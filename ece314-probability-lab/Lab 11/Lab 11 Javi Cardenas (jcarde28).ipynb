# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')
# Out:
# Text(0.5, 0, 'y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
### Part 1 ###
print('Part 1 - Mean Lifetime')

# Code given above
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)


# Calculate the mean lifetime
h_const = t_max/1000
mean_lifetime = 0

for i in range(1000):
    mean_lifetime += 1 - F[i][0]
    
mean_lifetime *= h_const   
print ('The mean lifetime is', round(mean_lifetime,5))



### Part 2 ###
print("\nPart 2 - Doubled Failure Rate F'n")

# Code given above
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return (1-t) * 2 # double the failure rate function
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3) * 2 # double the failure rate function
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)


# Calculate the mean lifetime
h_const = t_max/1000
mean_lifetime = 0

for i in range(1000):
    mean_lifetime += 1 - F[i][0]
    
mean_lifetime *= h_const    
print ('The mean lifetime is', round(mean_lifetime,5))
# Out:
# Part 1 - Mean Lifetime
# The mean lifetime is 2.65652
#
# Part 2 - Doubled Failure Rate F'n
# The mean lifetime is 1.55044

# %% [markdown]
# __Answer:__
# 2) When the failure rate function is doubled for all time, the mean lifetime decreases.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 1000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 a small meets a large    [ 5 12] [0.29411765 0.70588235]
# Round 2 two large crickets meet  [ 5 18] [0.2173913 0.7826087]
# Round 3 two large crickets meet  [ 5 24] [0.17241379 0.82758621]
# Round 4 two large crickets meet  [ 5 30] [0.14285714 0.85714286]
# Round 5 two large crickets meet  [ 5 36] [0.12195122 0.87804878]
# Round 6 two large crickets meet  [ 5 42] [0.10638298 0.89361702]
# Round 7 two large crickets meet  [ 5 48] [0.09433962 0.90566038]
# Round 8 a small meets a large    [ 6 56] [0.09677419 0.90322581]
# Round 9 a small meets a large    [ 7 64] [0.09859155 0.90140845]
# Round 10 two large crickets meet  [ 7 70] [0.09090909 0.90909091]
# Round 11 two large crickets meet  [ 7 76] [0.08433735 0.91566265]
# Round 12 two large crickets meet  [ 7 82] [0.07865169 0.92134831]
# Round 13 two large crickets meet  [ 7 88] [0.07368421 0.92631579]
# Round 14 two large crickets meet  [ 7 94] [0.06930693 0.93069307]
# Round 15 two large crickets meet  [  7 100] [0.06542056 0.93457944]
# Round 16 two large crickets meet  [  7 106] [0.0619469 0.9380531]
# Round 17 two large crickets meet  [  7 112] [0.05882353 0.94117647]
# Round 18 two large crickets meet  [  7 118] [0.056 0.944]
# Round 19 two large crickets meet  [  7 124] [0.05343511 0.94656489]
# Round 20 two large crickets meet  [  7 130] [0.05109489 0.94890511]
# Round 21 two large crickets meet  [  7 136] [0.04895105 0.95104895]
# Round 22 two large crickets meet  [  7 142] [0.04697987 0.95302013]
# Round 23 two large crickets meet  [  7 148] [0.04516129 0.95483871]
# Round 24 two large crickets meet  [  7 154] [0.04347826 0.95652174]
# Round 25 two large crickets meet  [  7 160] [0.04191617 0.95808383]
# Round 26 two large crickets meet  [  7 166] [0.04046243 0.95953757]
# Round 27 two large crickets meet  [  7 172] [0.03910615 0.96089385]
# Round 28 two large crickets meet  [  7 178] [0.03783784 0.96216216]
# Round 29 a small meets a large    [  8 186] [0.04123711 0.95876289]
# Round 30 two large crickets meet  [  8 192] [0.04 0.96]
# Round 31 two large crickets meet  [  8 198] [0.03883495 0.96116505]
# Round 32 two large crickets meet  [  8 204] [0.03773585 0.96226415]
# Round 33 two large crickets meet  [  8 210] [0.03669725 0.96330275]
# Round 34 two large crickets meet  [  8 216] [0.03571429 0.96428571]
# Round 35 two large crickets meet  [  8 222] [0.03478261 0.96521739]
# Round 36 two large crickets meet  [  8 228] [0.03389831 0.96610169]
# Round 37 a small meets a large    [  9 236] [0.03673469 0.96326531]
# Round 38 two large crickets meet  [  9 242] [0.03585657 0.96414343]
# Round 39 two large crickets meet  [  9 248] [0.03501946 0.96498054]
# Round 40 two large crickets meet  [  9 254] [0.03422053 0.96577947]
# Round 41 two large crickets meet  [  9 260] [0.03345725 0.96654275]
# Round 42 two large crickets meet  [  9 266] [0.03272727 0.96727273]
# Round 43 two large crickets meet  [  9 272] [0.03202847 0.96797153]
# Round 44 two large crickets meet  [  9 278] [0.03135889 0.96864111]
# Round 45 two large crickets meet  [  9 284] [0.03071672 0.96928328]
# Round 46 two large crickets meet  [  9 290] [0.03010033 0.96989967]
# Round 47 two large crickets meet  [  9 296] [0.0295082 0.9704918]
# Round 48 two large crickets meet  [  9 302] [0.02893891 0.97106109]
# Round 49 two large crickets meet  [  9 308] [0.02839117 0.97160883]
# Round 50 two large crickets meet  [  9 314] [0.02786378 0.97213622]
# Round 51 a small meets a large    [ 10 322] [0.03012048 0.96987952]
# Round 52 two large crickets meet  [ 10 328] [0.0295858 0.9704142]
# Round 53 two large crickets meet  [ 10 334] [0.02906977 0.97093023]
# Round 54 two large crickets meet  [ 10 340] [0.02857143 0.97142857]
# Round 55 two large crickets meet  [ 10 346] [0.02808989 0.97191011]
# Round 56 two large crickets meet  [ 10 352] [0.02762431 0.97237569]
# Round 57 two large crickets meet  [ 10 358] [0.02717391 0.97282609]
# Round 58 two large crickets meet  [ 10 364] [0.02673797 0.97326203]
# Round 59 two large crickets meet  [ 10 370] [0.02631579 0.97368421]
# Round 60 two large crickets meet  [ 10 376] [0.02590674 0.97409326]
# Round 61 two large crickets meet  [ 10 382] [0.0255102 0.9744898]
# Round 62 a small meets a large    [ 11 390] [0.02743142 0.97256858]
# Round 63 two large crickets meet  [ 11 396] [0.02702703 0.97297297]
# Round 64 two large crickets meet  [ 11 402] [0.02663438 0.97336562]
# Round 65 two large crickets meet  [ 11 408] [0.02625298 0.97374702]
# Round 66 two large crickets meet  [ 11 414] [0.02588235 0.97411765]
# Round 67 two large crickets meet  [ 11 420] [0.02552204 0.97447796]
# Round 68 two large crickets meet  [ 11 426] [0.02517162 0.97482838]
# Round 69 two large crickets meet  [ 11 432] [0.0248307 0.9751693]
# Round 70 two large crickets meet  [ 11 438] [0.02449889 0.97550111]
# Round 71 two large crickets meet  [ 11 444] [0.02417582 0.97582418]
# Round 72 two large crickets meet  [ 11 450] [0.02386117 0.97613883]
# Round 73 a small meets a large    [ 12 458] [0.02553191 0.97446809]
# Round 74 two large crickets meet  [ 12 464] [0.02521008 0.97478992]
# Round 75 two large crickets meet  [ 12 470] [0.02489627 0.97510373]
# Round 76 two large crickets meet  [ 12 476] [0.02459016 0.97540984]
# Round 77 two large crickets meet  [ 12 482] [0.0242915 0.9757085]
# Round 78 two large crickets meet  [ 12 488] [0.024 0.976]
# Round 79 two large crickets meet  [ 12 494] [0.02371542 0.97628458]
# Round 80 two large crickets meet  [ 12 500] [0.0234375 0.9765625]
# Round 81 two large crickets meet  [ 12 506] [0.02316602 0.97683398]
# Round 82 two large crickets meet  [ 12 512] [0.02290076 0.97709924]
# Round 83 two large crickets meet  [ 12 518] [0.02264151 0.97735849]
# Round 84 two large crickets meet  [ 12 524] [0.02238806 0.97761194]
# Round 85 two large crickets meet  [ 12 530] [0.02214022 0.97785978]
# Round 86 two large crickets meet  [ 12 536] [0.02189781 0.97810219]
# Round 87 two large crickets meet  [ 12 542] [0.02166065 0.97833935]
# Round 88 two large crickets meet  [ 12 548] [0.02142857 0.97857143]
# Round 89 two large crickets meet  [ 12 554] [0.02120141 0.97879859]
# Round 90 two large crickets meet  [ 12 560] [0.02097902 0.97902098]
# Round 91 two large crickets meet  [ 12 566] [0.02076125 0.97923875]
# Round 92 two large crickets meet  [ 12 572] [0.02054795 0.97945205]
# Round 93 two large crickets meet  [ 12 578] [0.02033898 0.97966102]
# Round 94 two large crickets meet  [ 12 584] [0.02013423 0.97986577]
# Round 95 two large crickets meet  [ 12 590] [0.01993355 0.98006645]
# Round 96 two large crickets meet  [ 12 596] [0.01973684 0.98026316]
# Round 97 two large crickets meet  [ 12 602] [0.01954397 0.98045603]
# Round 98 two large crickets meet  [ 12 608] [0.01935484 0.98064516]
# Round 99 two large crickets meet  [ 12 614] [0.01916933 0.98083067]
# Round 100 two large crickets meet  [ 12 620] [0.01898734 0.98101266]
# Round 101 two large crickets meet  [ 12 626] [0.01880878 0.98119122]
# Round 102 two large crickets meet  [ 12 632] [0.01863354 0.98136646]
# Round 103 two large crickets meet  [ 12 638] [0.01846154 0.98153846]
# Round 104 two large crickets meet  [ 12 644] [0.01829268 0.98170732]
# Round 105 two large crickets meet  [ 12 650] [0.01812689 0.98187311]
# Round 106 two large crickets meet  [ 12 656] [0.01796407 0.98203593]
# Round 107 two large crickets meet  [ 12 662] [0.01780415 0.98219585]
# Round 108 two large crickets meet  [ 12 668] [0.01764706 0.98235294]
# Round 109 two large crickets meet  [ 12 674] [0.01749271 0.98250729]
# Round 110 two large crickets meet  [ 12 680] [0.01734104 0.98265896]
# Round 111 two large crickets meet  [ 12 686] [0.01719198 0.98280802]
# Round 112 two large crickets meet  [ 12 692] [0.01704545 0.98295455]
# Round 113 two large crickets meet  [ 12 698] [0.01690141 0.98309859]
# Round 114 two large crickets meet  [ 12 704] [0.01675978 0.98324022]
# Round 115 two large crickets meet  [ 12 710] [0.0166205 0.9833795]
# Round 116 two large crickets meet  [ 12 716] [0.01648352 0.98351648]
# Round 117 two large crickets meet  [ 12 722] [0.01634877 0.98365123]
# Round 118 two large crickets meet  [ 12 728] [0.01621622 0.98378378]
# Round 119 two large crickets meet  [ 12 734] [0.01608579 0.98391421]
# Round 120 two large crickets meet  [ 12 740] [0.01595745 0.98404255]
# Round 121 two large crickets meet  [ 12 746] [0.01583113 0.98416887]
# Round 122 two large crickets meet  [ 12 752] [0.01570681 0.98429319]
# Round 123 two large crickets meet  [ 12 758] [0.01558442 0.98441558]
# Round 124 two large crickets meet  [ 12 764] [0.01546392 0.98453608]
# Round 125 two large crickets meet  [ 12 770] [0.01534527 0.98465473]
# Round 126 two large crickets meet  [ 12 776] [0.01522843 0.98477157]
# Round 127 two large crickets meet  [ 12 782] [0.01511335 0.98488665]
# Round 128 two large crickets meet  [ 12 788] [0.015 0.985]
# Round 129 two large crickets meet  [ 12 794] [0.01488834 0.98511166]
# Round 130 two large crickets meet  [ 12 800] [0.01477833 0.98522167]
# Round 131 two large crickets meet  [ 12 806] [0.01466993 0.98533007]
# Round 132 two large crickets meet  [ 12 812] [0.01456311 0.98543689]
# Round 133 two large crickets meet  [ 12 818] [0.01445783 0.98554217]
# Round 134 two large crickets meet  [ 12 824] [0.01435407 0.98564593]
# Round 135 two large crickets meet  [ 12 830] [0.01425178 0.98574822]
# Round 136 two large crickets meet  [ 12 836] [0.01415094 0.98584906]
# Round 137 two large crickets meet  [ 12 842] [0.01405152 0.98594848]
# Round 138 two large crickets meet  [ 12 848] [0.01395349 0.98604651]
# Round 139 two large crickets meet  [ 12 854] [0.01385681 0.98614319]
# Round 140 two large crickets meet  [ 12 860] [0.01376147 0.98623853]
# Round 141 two large crickets meet  [ 12 866] [0.01366743 0.98633257]
# Round 142 two large crickets meet  [ 12 872] [0.01357466 0.98642534]
# Round 143 two large crickets meet  [ 12 878] [0.01348315 0.98651685]
# Round 144 two large crickets meet  [ 12 884] [0.01339286 0.98660714]
# Round 145 two large crickets meet  [ 12 890] [0.01330377 0.98669623]
# Round 146 two large crickets meet  [ 12 896] [0.01321586 0.98678414]
# Round 147 two large crickets meet  [ 12 902] [0.0131291 0.9868709]
# Round 148 two large crickets meet  [ 12 908] [0.01304348 0.98695652]
# Round 149 two large crickets meet  [ 12 914] [0.01295896 0.98704104]
# Round 150 two large crickets meet  [ 12 920] [0.01287554 0.98712446]
# Round 151 two large crickets meet  [ 12 926] [0.01279318 0.98720682]
# Round 152 two large crickets meet  [ 12 932] [0.01271186 0.98728814]
# Round 153 two large crickets meet  [ 12 938] [0.01263158 0.98736842]
# Round 154 two large crickets meet  [ 12 944] [0.0125523 0.9874477]
# Round 155 two large crickets meet  [ 12 950] [0.01247401 0.98752599]
# Round 156 two large crickets meet  [ 12 956] [0.01239669 0.98760331]
# Round 157 two large crickets meet  [ 12 962] [0.01232033 0.98767967]
# Round 158 two large crickets meet  [ 12 968] [0.0122449 0.9877551]
# Round 159 a small meets a large    [ 13 976] [0.01314459 0.98685541]
# Round 160 two large crickets meet  [ 13 982] [0.01306533 0.98693467]
# Round 161 two large crickets meet  [ 13 988] [0.01298701 0.98701299]
# Round 162 two large crickets meet  [ 13 994] [0.01290963 0.98709037]
# Round 163 two large crickets meet  [  13 1000] [0.01283317 0.98716683]
# Round 164 two large crickets meet  [  13 1006] [0.01275761 0.98724239]
# Round 165 two large crickets meet  [  13 1012] [0.01268293 0.98731707]
# Round 166 two large crickets meet  [  13 1018] [0.01260912 0.98739088]
# Round 167 two large crickets meet  [  13 1024] [0.01253616 0.98746384]
# Round 168 two large crickets meet  [  13 1030] [0.01246405 0.98753595]
# Round 169 two large crickets meet  [  13 1036] [0.01239276 0.98760724]
# Round 170 two large crickets meet  [  13 1042] [0.01232227 0.98767773]
# Round 171 two large crickets meet  [  13 1048] [0.01225259 0.98774741]
# Round 172 two large crickets meet  [  13 1054] [0.01218369 0.98781631]
# Round 173 two large crickets meet  [  13 1060] [0.01211556 0.98788444]
# Round 174 two large crickets meet  [  13 1066] [0.01204819 0.98795181]
# Round 175 two large crickets meet  [  13 1072] [0.01198157 0.98801843]
# Round 176 two large crickets meet  [  13 1078] [0.01191567 0.98808433]
# Round 177 two large crickets meet  [  13 1084] [0.0118505 0.9881495]
# Round 178 a small meets a large    [  14 1092] [0.01265823 0.98734177]
# Round 179 two large crickets meet  [  14 1098] [0.01258993 0.98741007]
# Round 180 two large crickets meet  [  14 1104] [0.01252236 0.98747764]
# Round 181 two large crickets meet  [  14 1110] [0.01245552 0.98754448]
# Round 182 two large crickets meet  [  14 1116] [0.01238938 0.98761062]
# Round 183 two large crickets meet  [  14 1122] [0.01232394 0.98767606]
# Round 184 two large crickets meet  [  14 1128] [0.01225919 0.98774081]
# Round 185 two large crickets meet  [  14 1134] [0.01219512 0.98780488]
# Round 186 two large crickets meet  [  14 1140] [0.01213172 0.98786828]
# Round 187 two large crickets meet  [  14 1146] [0.01206897 0.98793103]
# Round 188 two large crickets meet  [  14 1152] [0.01200686 0.98799314]
# Round 189 two large crickets meet  [  14 1158] [0.01194539 0.98805461]
# Round 190 two large crickets meet  [  14 1164] [0.01188455 0.98811545]
# Round 191 two large crickets meet  [  14 1170] [0.01182432 0.98817568]
# Round 192 two large crickets meet  [  14 1176] [0.01176471 0.98823529]
# Round 193 two large crickets meet  [  14 1182] [0.01170569 0.98829431]
# Round 194 two large crickets meet  [  14 1188] [0.01164725 0.98835275]
# Round 195 two large crickets meet  [  14 1194] [0.0115894 0.9884106]
# Round 196 two large crickets meet  [  14 1200] [0.01153213 0.98846787]
# Round 197 two large crickets meet  [  14 1206] [0.01147541 0.98852459]
# Round 198 two large crickets meet  [  14 1212] [0.01141925 0.98858075]
# Round 199 two large crickets meet  [  14 1218] [0.01136364 0.98863636]
# Round 200 two large crickets meet  [  14 1224] [0.01130856 0.98869144]
# Round 201 two large crickets meet  [  14 1230] [0.01125402 0.98874598]
# Round 202 two large crickets meet  [  14 1236] [0.0112 0.9888]
# Round 203 two large crickets meet  [  14 1242] [0.0111465 0.9888535]
# Round 204 two large crickets meet  [  14 1248] [0.0110935 0.9889065]
# Round 205 two large crickets meet  [  14 1254] [0.01104101 0.98895899]
# Round 206 two large crickets meet  [  14 1260] [0.01098901 0.98901099]
# Round 207 a small meets a large    [  15 1268] [0.01169135 0.98830865]
# Round 208 two large crickets meet  [  15 1274] [0.01163693 0.98836307]
# Round 209 two large crickets meet  [  15 1280] [0.01158301 0.98841699]
# Round 210 two large crickets meet  [  15 1286] [0.01152959 0.98847041]
# Round 211 two large crickets meet  [  15 1292] [0.01147666 0.98852334]
# Round 212 two large crickets meet  [  15 1298] [0.01142422 0.98857578]
# Round 213 two large crickets meet  [  15 1304] [0.01137225 0.98862775]
# Round 214 two large crickets meet  [  15 1310] [0.01132075 0.98867925]
# Round 215 two large crickets meet  [  15 1316] [0.01126972 0.98873028]
# Round 216 two large crickets meet  [  15 1322] [0.01121915 0.98878085]
# Round 217 two large crickets meet  [  15 1328] [0.01116902 0.98883098]
# Round 218 two large crickets meet  [  15 1334] [0.01111935 0.98888065]
# Round 219 two large crickets meet  [  15 1340] [0.01107011 0.98892989]
# Round 220 two large crickets meet  [  15 1346] [0.01102131 0.98897869]
# Round 221 two large crickets meet  [  15 1352] [0.01097293 0.98902707]
# Round 222 two large crickets meet  [  15 1358] [0.01092498 0.98907502]
# Round 223 a small meets a large    [  16 1366] [0.01157742 0.98842258]
# Round 224 two large crickets meet  [  16 1372] [0.01152738 0.98847262]
# Round 225 two large crickets meet  [  16 1378] [0.01147776 0.98852224]
# Round 226 two large crickets meet  [  16 1384] [0.01142857 0.98857143]
# Round 227 two large crickets meet  [  16 1390] [0.0113798 0.9886202]
# Round 228 two large crickets meet  [  16 1396] [0.01133144 0.98866856]
# Round 229 two large crickets meet  [  16 1402] [0.0112835 0.9887165]
# Round 230 two large crickets meet  [  16 1408] [0.01123596 0.98876404]
# Round 231 two large crickets meet  [  16 1414] [0.01118881 0.98881119]
# Round 232 two large crickets meet  [  16 1420] [0.01114206 0.98885794]
# Round 233 two large crickets meet  [  16 1426] [0.0110957 0.9889043]
# Round 234 two large crickets meet  [  16 1432] [0.01104972 0.98895028]
# Round 235 two large crickets meet  [  16 1438] [0.01100413 0.98899587]
# Round 236 two large crickets meet  [  16 1444] [0.0109589 0.9890411]
# Round 237 two large crickets meet  [  16 1450] [0.01091405 0.98908595]
# Round 238 two large crickets meet  [  16 1456] [0.01086957 0.98913043]
# Round 239 two large crickets meet  [  16 1462] [0.01082544 0.98917456]
# Round 240 two large crickets meet  [  16 1468] [0.01078167 0.98921833]
# Round 241 two large crickets meet  [  16 1474] [0.01073826 0.98926174]
# Round 242 two large crickets meet  [  16 1480] [0.01069519 0.98930481]
# Round 243 two large crickets meet  [  16 1486] [0.01065246 0.98934754]
# Round 244 two large crickets meet  [  16 1492] [0.01061008 0.98938992]
# Round 245 two large crickets meet  [  16 1498] [0.01056803 0.98943197]
# Round 246 two large crickets meet  [  16 1504] [0.01052632 0.98947368]
# Round 247 two large crickets meet  [  16 1510] [0.01048493 0.98951507]
# Round 248 two large crickets meet  [  16 1516] [0.01044386 0.98955614]
# Round 249 a small meets a large    [  17 1524] [0.0110318 0.9889682]
# Round 250 two large crickets meet  [  17 1530] [0.01098901 0.98901099]
# Round 251 two large crickets meet  [  17 1536] [0.01094656 0.98905344]
# Round 252 two large crickets meet  [  17 1542] [0.01090443 0.98909557]
# Round 253 two large crickets meet  [  17 1548] [0.01086262 0.98913738]
# Round 254 two large crickets meet  [  17 1554] [0.01082113 0.98917887]
# Round 255 two large crickets meet  [  17 1560] [0.01077996 0.98922004]
# Round 256 two large crickets meet  [  17 1566] [0.0107391 0.9892609]
# Round 257 two large crickets meet  [  17 1572] [0.01069855 0.98930145]
# Round 258 two large crickets meet  [  17 1578] [0.01065831 0.98934169]
# Round 259 two large crickets meet  [  17 1584] [0.01061836 0.98938164]
# Round 260 two large crickets meet  [  17 1590] [0.01057872 0.98942128]
# Round 261 two large crickets meet  [  17 1596] [0.01053937 0.98946063]
# Round 262 two large crickets meet  [  17 1602] [0.01050031 0.98949969]
# Round 263 two large crickets meet  [  17 1608] [0.01046154 0.98953846]
# Round 264 two large crickets meet  [  17 1614] [0.01042305 0.98957695]
# Round 265 two large crickets meet  [  17 1620] [0.01038485 0.98961515]
# Round 266 two large crickets meet  [  17 1626] [0.01034693 0.98965307]
# Round 267 two large crickets meet  [  17 1632] [0.01030928 0.98969072]
# Round 268 two large crickets meet  [  17 1638] [0.0102719 0.9897281]
# Round 269 two large crickets meet  [  17 1644] [0.0102348 0.9897652]
# Round 270 two large crickets meet  [  17 1650] [0.01019796 0.98980204]
# Round 271 two large crickets meet  [  17 1656] [0.01016139 0.98983861]
# Round 272 two large crickets meet  [  17 1662] [0.01012507 0.98987493]
# Round 273 two large crickets meet  [  17 1668] [0.01008902 0.98991098]
# Round 274 two large crickets meet  [  17 1674] [0.01005322 0.98994678]
# Round 275 two large crickets meet  [  17 1680] [0.01001768 0.98998232]
# Round 276 two large crickets meet  [  17 1686] [0.00998238 0.99001762]
# Round 277 two large crickets meet  [  17 1692] [0.00994734 0.99005266]
# Round 278 two large crickets meet  [  17 1698] [0.00991254 0.99008746]
# Round 279 two large crickets meet  [  17 1704] [0.00987798 0.99012202]
# Round 280 two large crickets meet  [  17 1710] [0.00984366 0.99015634]
# Round 281 two large crickets meet  [  17 1716] [0.00980958 0.99019042]
# Round 282 two large crickets meet  [  17 1722] [0.00977573 0.99022427]
# Round 283 two large crickets meet  [  17 1728] [0.00974212 0.99025788]
# Round 284 two large crickets meet  [  17 1734] [0.00970874 0.99029126]
# Round 285 two large crickets meet  [  17 1740] [0.00967558 0.99032442]
# Round 286 two large crickets meet  [  17 1746] [0.00964265 0.99035735]
# Round 287 two large crickets meet  [  17 1752] [0.00960995 0.99039005]
# Round 288 two large crickets meet  [  17 1758] [0.00957746 0.99042254]
# Round 289 two large crickets meet  [  17 1764] [0.0095452 0.9904548]
# Round 290 two large crickets meet  [  17 1770] [0.00951315 0.99048685]
# Round 291 two large crickets meet  [  17 1776] [0.00948132 0.99051868]
# Round 292 two large crickets meet  [  17 1782] [0.00944969 0.99055031]
# Round 293 two large crickets meet  [  17 1788] [0.00941828 0.99058172]
# Round 294 two large crickets meet  [  17 1794] [0.00938708 0.99061292]
# Round 295 two large crickets meet  [  17 1800] [0.00935608 0.99064392]
# Round 296 two large crickets meet  [  17 1806] [0.00932529 0.99067471]
# Round 297 two large crickets meet  [  17 1812] [0.0092947 0.9907053]
# Round 298 two large crickets meet  [  17 1818] [0.00926431 0.99073569]
# Round 299 two large crickets meet  [  17 1824] [0.00923411 0.99076589]
# Round 300 two large crickets meet  [  17 1830] [0.00920411 0.99079589]
# Round 301 two large crickets meet  [  17 1836] [0.00917431 0.99082569]
# Round 302 two large crickets meet  [  17 1842] [0.0091447 0.9908553]
# Round 303 two large crickets meet  [  17 1848] [0.00911528 0.99088472]
# Round 304 two large crickets meet  [  17 1854] [0.00908605 0.99091395]
# Round 305 two large crickets meet  [  17 1860] [0.00905701 0.99094299]
# Round 306 two large crickets meet  [  17 1866] [0.00902815 0.99097185]
# Round 307 two large crickets meet  [  17 1872] [0.00899947 0.99100053]
# Round 308 two large crickets meet  [  17 1878] [0.00897098 0.99102902]
# Round 309 a small meets a large    [  18 1886] [0.00945378 0.99054622]
# Round 310 two large crickets meet  [  18 1892] [0.00942408 0.99057592]
# Round 311 two large crickets meet  [  18 1898] [0.00939457 0.99060543]
# Round 312 two large crickets meet  [  18 1904] [0.00936524 0.99063476]
# Round 313 two large crickets meet  [  18 1910] [0.0093361 0.9906639]
# Round 314 a small meets a large    [  19 1918] [0.00980898 0.99019102]
# Round 315 two large crickets meet  [  19 1924] [0.00977869 0.99022131]
# Round 316 two large crickets meet  [  19 1930] [0.00974859 0.99025141]
# Round 317 two large crickets meet  [  19 1936] [0.00971867 0.99028133]
# Round 318 two large crickets meet  [  19 1942] [0.00968893 0.99031107]
# Round 319 two large crickets meet  [  19 1948] [0.00965938 0.99034062]
# Round 320 two large crickets meet  [  19 1954] [0.00963001 0.99036999]
# Round 321 two large crickets meet  [  19 1960] [0.00960081 0.99039919]
# Round 322 two large crickets meet  [  19 1966] [0.00957179 0.99042821]
# Round 323 two large crickets meet  [  19 1972] [0.00954294 0.99045706]
# Round 324 two large crickets meet  [  19 1978] [0.00951427 0.99048573]
# Round 325 two large crickets meet  [  19 1984] [0.00948577 0.99051423]
# Round 326 two large crickets meet  [  19 1990] [0.00945744 0.99054256]
# Round 327 two large crickets meet  [  19 1996] [0.00942928 0.99057072]
# Round 328 two large crickets meet  [  19 2002] [0.00940129 0.99059871]
# Round 329 two large crickets meet  [  19 2008] [0.00937346 0.99062654]
# Round 330 two large crickets meet  [  19 2014] [0.00934579 0.99065421]
# Round 331 two large crickets meet  [  19 2020] [0.00931829 0.99068171]
# Round 332 two large crickets meet  [  19 2026] [0.00929095 0.99070905]
# Round 333 two large crickets meet  [  19 2032] [0.00926377 0.99073623]
# Round 334 two large crickets meet  [  19 2038] [0.00923675 0.99076325]
# Round 335 two large crickets meet  [  19 2044] [0.00920989 0.99079011]
# Round 336 two large crickets meet  [  19 2050] [0.00918318 0.99081682]
# Round 337 two large crickets meet  [  19 2056] [0.00915663 0.99084337]
# Round 338 two large crickets meet  [  19 2062] [0.00913023 0.99086977]
# Round 339 two large crickets meet  [  19 2068] [0.00910398 0.99089602]
# Round 340 two large crickets meet  [  19 2074] [0.00907788 0.99092212]
# Round 341 two large crickets meet  [  19 2080] [0.00905193 0.99094807]
# Round 342 two large crickets meet  [  19 2086] [0.00902613 0.99097387]
# Round 343 two large crickets meet  [  19 2092] [0.00900047 0.99099953]
# Round 344 two large crickets meet  [  19 2098] [0.00897496 0.99102504]
# Round 345 two large crickets meet  [  19 2104] [0.0089496 0.9910504]
# Round 346 two large crickets meet  [  19 2110] [0.00892438 0.99107562]
# Round 347 two large crickets meet  [  19 2116] [0.0088993 0.9911007]
# Round 348 two large crickets meet  [  19 2122] [0.00887436 0.99112564]
# Round 349 two large crickets meet  [  19 2128] [0.00884956 0.99115044]
# Round 350 two large crickets meet  [  19 2134] [0.0088249 0.9911751]
# Round 351 two large crickets meet  [  19 2140] [0.00880037 0.99119963]
# Round 352 two large crickets meet  [  19 2146] [0.00877598 0.99122402]
# Round 353 two large crickets meet  [  19 2152] [0.00875173 0.99124827]
# Round 354 two large crickets meet  [  19 2158] [0.00872761 0.99127239]
# Round 355 two large crickets meet  [  19 2164] [0.00870362 0.99129638]
# Round 356 two large crickets meet  [  19 2170] [0.00867976 0.99132024]
# Round 357 two large crickets meet  [  19 2176] [0.00865604 0.99134396]
# Round 358 two large crickets meet  [  19 2182] [0.00863244 0.99136756]
# Round 359 two large crickets meet  [  19 2188] [0.00860897 0.99139103]
# Round 360 two large crickets meet  [  19 2194] [0.00858563 0.99141437]
# Round 361 two large crickets meet  [  19 2200] [0.00856242 0.99143758]
# Round 362 two large crickets meet  [  19 2206] [0.00853933 0.99146067]
# Round 363 two large crickets meet  [  19 2212] [0.00851636 0.99148364]
# Round 364 two large crickets meet  [  19 2218] [0.00849352 0.99150648]
# Round 365 two large crickets meet  [  19 2224] [0.0084708 0.9915292]
# Round 366 two large crickets meet  [  19 2230] [0.0084482 0.9915518]
# Round 367 two large crickets meet  [  19 2236] [0.00842572 0.99157428]
# Round 368 two large crickets meet  [  19 2242] [0.00840336 0.99159664]
# Round 369 two large crickets meet  [  19 2248] [0.00838112 0.99161888]
# Round 370 two large crickets meet  [  19 2254] [0.008359 0.991641]
# Round 371 two large crickets meet  [  19 2260] [0.00833699 0.99166301]
# Round 372 two large crickets meet  [  19 2266] [0.0083151 0.9916849]
# Round 373 two large crickets meet  [  19 2272] [0.00829332 0.99170668]
# Round 374 two large crickets meet  [  19 2278] [0.00827166 0.99172834]
# Round 375 two large crickets meet  [  19 2284] [0.00825011 0.99174989]
# Round 376 two large crickets meet  [  19 2290] [0.00822867 0.99177133]
# Round 377 two large crickets meet  [  19 2296] [0.00820734 0.99179266]
# Round 378 two large crickets meet  [  19 2302] [0.00818613 0.99181387]
# Round 379 two large crickets meet  [  19 2308] [0.00816502 0.99183498]
# Round 380 two large crickets meet  [  19 2314] [0.00814402 0.99185598]
# Round 381 two large crickets meet  [  19 2320] [0.00812313 0.99187687]
# Round 382 two large crickets meet  [  19 2326] [0.00810235 0.99189765]
# Round 383 two large crickets meet  [  19 2332] [0.00808167 0.99191833]
# Round 384 two large crickets meet  [  19 2338] [0.00806109 0.99193891]
# Round 385 two large crickets meet  [  19 2344] [0.00804063 0.99195937]
# Round 386 two large crickets meet  [  19 2350] [0.00802026 0.99197974]
# Round 387 two large crickets meet  [  19 2356] [0.008 0.992]
# Round 388 two large crickets meet  [  19 2362] [0.00797984 0.99202016]
# Round 389 two large crickets meet  [  19 2368] [0.00795978 0.99204022]
# Round 390 two large crickets meet  [  19 2374] [0.00793982 0.99206018]
# Round 391 two large crickets meet  [  19 2380] [0.00791997 0.99208003]
# Round 392 two large crickets meet  [  19 2386] [0.00790021 0.99209979]
# Round 393 two large crickets meet  [  19 2392] [0.00788055 0.99211945]
# Round 394 two large crickets meet  [  19 2398] [0.00786098 0.99213902]
# Round 395 two large crickets meet  [  19 2404] [0.00784152 0.99215848]
# Round 396 two large crickets meet  [  19 2410] [0.00782215 0.99217785]
# Round 397 two large crickets meet  [  19 2416] [0.00780287 0.99219713]
# Round 398 two large crickets meet  [  19 2422] [0.0077837 0.9922163]
# Round 399 two large crickets meet  [  19 2428] [0.00776461 0.99223539]
# Round 400 two large crickets meet  [  19 2434] [0.00774562 0.99225438]
# Round 401 two large crickets meet  [  19 2440] [0.00772672 0.99227328]
# Round 402 two large crickets meet  [  19 2446] [0.00770791 0.99229209]
# Round 403 two large crickets meet  [  19 2452] [0.00768919 0.99231081]
# Round 404 two large crickets meet  [  19 2458] [0.00767057 0.99232943]
# Round 405 two large crickets meet  [  19 2464] [0.00765203 0.99234797]
# Round 406 two large crickets meet  [  19 2470] [0.00763359 0.99236641]
# Round 407 two large crickets meet  [  19 2476] [0.00761523 0.99238477]
# Round 408 two large crickets meet  [  19 2482] [0.00759696 0.99240304]
# Round 409 two large crickets meet  [  19 2488] [0.00757878 0.99242122]
# Round 410 two large crickets meet  [  19 2494] [0.00756068 0.99243932]
# Round 411 two large crickets meet  [  19 2500] [0.00754268 0.99245732]
# Round 412 two large crickets meet  [  19 2506] [0.00752475 0.99247525]
# Round 413 two large crickets meet  [  19 2512] [0.00750691 0.99249309]
# Round 414 two large crickets meet  [  19 2518] [0.00748916 0.99251084]
# Round 415 two large crickets meet  [  19 2524] [0.00747149 0.99252851]
# Round 416 two large crickets meet  [  19 2530] [0.0074539 0.9925461]
# Round 417 two large crickets meet  [  19 2536] [0.0074364 0.9925636]
# Round 418 two large crickets meet  [  19 2542] [0.00741898 0.99258102]
# Round 419 two large crickets meet  [  19 2548] [0.00740164 0.99259836]
# Round 420 two large crickets meet  [  19 2554] [0.00738438 0.99261562]
# Round 421 two large crickets meet  [  19 2560] [0.0073672 0.9926328]
# Round 422 two large crickets meet  [  19 2566] [0.0073501 0.9926499]
# Round 423 a small meets a large    [  20 2574] [0.0077101 0.9922899]
# Round 424 two large crickets meet  [  20 2580] [0.00769231 0.99230769]
# Round 425 two large crickets meet  [  20 2586] [0.0076746 0.9923254]
# Round 426 two large crickets meet  [  20 2592] [0.00765697 0.99234303]
# Round 427 two large crickets meet  [  20 2598] [0.00763942 0.99236058]
# Round 428 two large crickets meet  [  20 2604] [0.00762195 0.99237805]
# Round 429 two large crickets meet  [  20 2610] [0.00760456 0.99239544]
# Round 430 two large crickets meet  [  20 2616] [0.00758725 0.99241275]
# Round 431 two large crickets meet  [  20 2622] [0.00757002 0.99242998]
# Round 432 two large crickets meet  [  20 2628] [0.00755287 0.99244713]
# Round 433 two large crickets meet  [  20 2634] [0.0075358 0.9924642]
# Round 434 two large crickets meet  [  20 2640] [0.0075188 0.9924812]
# Round 435 two large crickets meet  [  20 2646] [0.00750188 0.99249812]
# Round 436 a small meets a large    [  21 2654] [0.00785047 0.99214953]
# Round 437 two large crickets meet  [  21 2660] [0.0078329 0.9921671]
# Round 438 two large crickets meet  [  21 2666] [0.00781541 0.99218459]
# Round 439 two large crickets meet  [  21 2672] [0.00779799 0.99220201]
# Round 440 two large crickets meet  [  21 2678] [0.00778066 0.99221934]
# Round 441 two large crickets meet  [  21 2684] [0.0077634 0.9922366]
# Round 442 two large crickets meet  [  21 2690] [0.00774622 0.99225378]
# Round 443 two large crickets meet  [  21 2696] [0.00772911 0.99227089]
# Round 444 two large crickets meet  [  21 2702] [0.00771208 0.99228792]
# Round 445 two large crickets meet  [  21 2708] [0.00769513 0.99230487]
# Round 446 two large crickets meet  [  21 2714] [0.00767824 0.99232176]
# Round 447 two large crickets meet  [  21 2720] [0.00766144 0.99233856]
# Round 448 two large crickets meet  [  21 2726] [0.0076447 0.9923553]
# Round 449 two large crickets meet  [  21 2732] [0.00762804 0.99237196]
# Round 450 two large crickets meet  [  21 2738] [0.00761145 0.99238855]
# Round 451 two large crickets meet  [  21 2744] [0.00759494 0.99240506]
# Round 452 two large crickets meet  [  21 2750] [0.00757849 0.99242151]
# Round 453 two large crickets meet  [  21 2756] [0.00756212 0.99243788]
# Round 454 two large crickets meet  [  21 2762] [0.00754581 0.99245419]
# Round 455 two large crickets meet  [  21 2768] [0.00752958 0.99247042]
# Round 456 a small meets a large    [  22 2776] [0.00786276 0.99213724]
# Round 457 two large crickets meet  [  22 2782] [0.00784593 0.99215407]
# Round 458 two large crickets meet  [  22 2788] [0.00782918 0.99217082]
# Round 459 two large crickets meet  [  22 2794] [0.0078125 0.9921875]
# Round 460 two large crickets meet  [  22 2800] [0.00779589 0.99220411]
# Round 461 two large crickets meet  [  22 2806] [0.00777935 0.99222065]
# Round 462 two large crickets meet  [  22 2812] [0.00776288 0.99223712]
# Round 463 two large crickets meet  [  22 2818] [0.00774648 0.99225352]
# Round 464 two large crickets meet  [  22 2824] [0.00773015 0.99226985]
# Round 465 two large crickets meet  [  22 2830] [0.00771388 0.99228612]
# Round 466 a small meets a large    [  23 2838] [0.00803915 0.99196085]
# Round 467 two large crickets meet  [  23 2844] [0.00802232 0.99197768]
# Round 468 two large crickets meet  [  23 2850] [0.00800557 0.99199443]
# Round 469 two large crickets meet  [  23 2856] [0.00798889 0.99201111]
# Round 470 two large crickets meet  [  23 2862] [0.00797227 0.99202773]
# Round 471 two large crickets meet  [  23 2868] [0.00795572 0.99204428]
# Round 472 two large crickets meet  [  23 2874] [0.00793925 0.99206075]
# Round 473 two large crickets meet  [  23 2880] [0.00792284 0.99207716]
# Round 474 two large crickets meet  [  23 2886] [0.0079065 0.9920935]
# Round 475 two large crickets meet  [  23 2892] [0.00789022 0.99210978]
# Round 476 two large crickets meet  [  23 2898] [0.00787402 0.99212598]
# Round 477 two large crickets meet  [  23 2904] [0.00785787 0.99214213]
# Round 478 two large crickets meet  [  23 2910] [0.0078418 0.9921582]
# Round 479 two large crickets meet  [  23 2916] [0.00782579 0.99217421]
# Round 480 two large crickets meet  [  23 2922] [0.00780985 0.99219015]
# Round 481 two large crickets meet  [  23 2928] [0.00779397 0.99220603]
# Round 482 two large crickets meet  [  23 2934] [0.00777815 0.99222185]
# Round 483 two large crickets meet  [  23 2940] [0.0077624 0.9922376]
# Round 484 two large crickets meet  [  23 2946] [0.00774672 0.99225328]
# Round 485 two large crickets meet  [  23 2952] [0.00773109 0.99226891]
# Round 486 two large crickets meet  [  23 2958] [0.00771553 0.99228447]
# Round 487 two large crickets meet  [  23 2964] [0.00770003 0.99229997]
# Round 488 two large crickets meet  [  23 2970] [0.0076846 0.9923154]
# Round 489 two large crickets meet  [  23 2976] [0.00766922 0.99233078]
# Round 490 two large crickets meet  [  23 2982] [0.00765391 0.99234609]
# Round 491 two large crickets meet  [  23 2988] [0.00763866 0.99236134]
# Round 492 two large crickets meet  [  23 2994] [0.00762347 0.99237653]
# Round 493 two large crickets meet  [  23 3000] [0.00760834 0.99239166]
# Round 494 two large crickets meet  [  23 3006] [0.00759327 0.99240673]
# Round 495 two large crickets meet  [  23 3012] [0.00757825 0.99242175]
# Round 496 two large crickets meet  [  23 3018] [0.0075633 0.9924367]
# Round 497 two large crickets meet  [  23 3024] [0.00754841 0.99245159]
# Round 498 two large crickets meet  [  23 3030] [0.00753357 0.99246643]
# Round 499 two large crickets meet  [  23 3036] [0.0075188 0.9924812]
# Round 500 two large crickets meet  [  23 3042] [0.00750408 0.99249592]
# Round 501 two large crickets meet  [  23 3048] [0.00748942 0.99251058]
# Round 502 two large crickets meet  [  23 3054] [0.00747481 0.99252519]
# Round 503 a small meets a large    [  24 3062] [0.00777706 0.99222294]
# Round 504 two large crickets meet  [  24 3068] [0.00776197 0.99223803]
# Round 505 two large crickets meet  [  24 3074] [0.00774693 0.99225307]
# Round 506 two large crickets meet  [  24 3080] [0.00773196 0.99226804]
# Round 507 two large crickets meet  [  24 3086] [0.00771704 0.99228296]
# Round 508 two large crickets meet  [  24 3092] [0.00770218 0.99229782]
# Round 509 two large crickets meet  [  24 3098] [0.00768738 0.99231262]
# Round 510 two large crickets meet  [  24 3104] [0.00767263 0.99232737]
# Round 511 two large crickets meet  [  24 3110] [0.00765795 0.99234205]
# Round 512 two large crickets meet  [  24 3116] [0.00764331 0.99235669]
# Round 513 two large crickets meet  [  24 3122] [0.00762873 0.99237127]
# Round 514 two large crickets meet  [  24 3128] [0.00761421 0.99238579]
# Round 515 two large crickets meet  [  24 3134] [0.00759975 0.99240025]
# Round 516 two large crickets meet  [  24 3140] [0.00758534 0.99241466]
# Round 517 two large crickets meet  [  24 3146] [0.00757098 0.99242902]
# Round 518 two large crickets meet  [  24 3152] [0.00755668 0.99244332]
# Round 519 two large crickets meet  [  24 3158] [0.00754243 0.99245757]
# Round 520 two large crickets meet  [  24 3164] [0.00752823 0.99247177]
# Round 521 two large crickets meet  [  24 3170] [0.00751409 0.99248591]
# Round 522 two large crickets meet  [  24 3176] [0.0075 0.9925]
# Round 523 two large crickets meet  [  24 3182] [0.00748596 0.99251404]
# Round 524 two large crickets meet  [  24 3188] [0.00747198 0.99252802]
# Round 525 two large crickets meet  [  24 3194] [0.00745805 0.99254195]
# Round 526 two large crickets meet  [  24 3200] [0.00744417 0.99255583]
# Round 527 two large crickets meet  [  24 3206] [0.00743034 0.99256966]
# Round 528 two large crickets meet  [  24 3212] [0.00741656 0.99258344]
# Round 529 two large crickets meet  [  24 3218] [0.00740284 0.99259716]
# Round 530 two large crickets meet  [  24 3224] [0.00738916 0.99261084]
# Round 531 two large crickets meet  [  24 3230] [0.00737554 0.99262446]
# Round 532 two large crickets meet  [  24 3236] [0.00736196 0.99263804]
# Round 533 two large crickets meet  [  24 3242] [0.00734844 0.99265156]
# Round 534 two large crickets meet  [  24 3248] [0.00733496 0.99266504]
# Round 535 two large crickets meet  [  24 3254] [0.00732154 0.99267846]
# Round 536 two large crickets meet  [  24 3260] [0.00730816 0.99269184]
# Round 537 two large crickets meet  [  24 3266] [0.00729483 0.99270517]
# Round 538 two large crickets meet  [  24 3272] [0.00728155 0.99271845]
# Round 539 two large crickets meet  [  24 3278] [0.00726832 0.99273168]
# Round 540 two large crickets meet  [  24 3284] [0.00725514 0.99274486]
# Round 541 two large crickets meet  [  24 3290] [0.007242 0.992758]
# Round 542 two large crickets meet  [  24 3296] [0.00722892 0.99277108]
# Round 543 two large crickets meet  [  24 3302] [0.00721587 0.99278413]
# Round 544 two large crickets meet  [  24 3308] [0.00720288 0.99279712]
# Round 545 two large crickets meet  [  24 3314] [0.00718993 0.99281007]
# Round 546 two large crickets meet  [  24 3320] [0.00717703 0.99282297]
# Round 547 two large crickets meet  [  24 3326] [0.00716418 0.99283582]
# Round 548 two large crickets meet  [  24 3332] [0.00715137 0.99284863]
# Round 549 two large crickets meet  [  24 3338] [0.00713861 0.99286139]
# Round 550 two large crickets meet  [  24 3344] [0.00712589 0.99287411]
# Round 551 two large crickets meet  [  24 3350] [0.00711322 0.99288678]
# Round 552 two large crickets meet  [  24 3356] [0.00710059 0.99289941]
# Round 553 two large crickets meet  [  24 3362] [0.00708801 0.99291199]
# Round 554 two large crickets meet  [  24 3368] [0.00707547 0.99292453]
# Round 555 two large crickets meet  [  24 3374] [0.00706298 0.99293702]
# Round 556 two large crickets meet  [  24 3380] [0.00705053 0.99294947]
# Round 557 two large crickets meet  [  24 3386] [0.00703812 0.99296188]
# Round 558 two large crickets meet  [  24 3392] [0.00702576 0.99297424]
# Round 559 two large crickets meet  [  24 3398] [0.00701344 0.99298656]
# Round 560 two large crickets meet  [  24 3404] [0.00700117 0.99299883]
# Round 561 two large crickets meet  [  24 3410] [0.00698893 0.99301107]
# Round 562 two large crickets meet  [  24 3416] [0.00697674 0.99302326]
# Round 563 two large crickets meet  [  24 3422] [0.0069646 0.9930354]
# Round 564 two large crickets meet  [  24 3428] [0.00695249 0.99304751]
# Round 565 two large crickets meet  [  24 3434] [0.00694043 0.99305957]
# Round 566 two large crickets meet  [  24 3440] [0.00692841 0.99307159]
# Round 567 two large crickets meet  [  24 3446] [0.00691643 0.99308357]
# Round 568 two large crickets meet  [  24 3452] [0.00690449 0.99309551]
# Round 569 two large crickets meet  [  24 3458] [0.00689259 0.99310741]
# Round 570 two large crickets meet  [  24 3464] [0.00688073 0.99311927]
# Round 571 two large crickets meet  [  24 3470] [0.00686892 0.99313108]
# Round 572 two large crickets meet  [  24 3476] [0.00685714 0.99314286]
# Round 573 two large crickets meet  [  24 3482] [0.00684541 0.99315459]
# Round 574 two large crickets meet  [  24 3488] [0.00683371 0.99316629]
# Round 575 two large crickets meet  [  24 3494] [0.00682206 0.99317794]
# Round 576 two large crickets meet  [  24 3500] [0.00681044 0.99318956]
# Round 577 two large crickets meet  [  24 3506] [0.00679887 0.99320113]
# Round 578 two large crickets meet  [  24 3512] [0.00678733 0.99321267]
# Round 579 two large crickets meet  [  24 3518] [0.00677583 0.99322417]
# Round 580 two large crickets meet  [  24 3524] [0.00676437 0.99323563]
# Round 581 two large crickets meet  [  24 3530] [0.00675295 0.99324705]
# Round 582 two large crickets meet  [  24 3536] [0.00674157 0.99325843]
# Round 583 two large crickets meet  [  24 3542] [0.00673023 0.99326977]
# Round 584 two large crickets meet  [  24 3548] [0.00671892 0.99328108]
# Round 585 two large crickets meet  [  24 3554] [0.00670766 0.99329234]
# Round 586 two large crickets meet  [  24 3560] [0.00669643 0.99330357]
# Round 587 two large crickets meet  [  24 3566] [0.00668524 0.99331476]
# Round 588 two large crickets meet  [  24 3572] [0.00667408 0.99332592]
# Round 589 two large crickets meet  [  24 3578] [0.00666297 0.99333703]
# Round 590 two large crickets meet  [  24 3584] [0.00665188 0.99334812]
# Round 591 two large crickets meet  [  24 3590] [0.00664084 0.99335916]
# Round 592 two large crickets meet  [  24 3596] [0.00662983 0.99337017]
# Round 593 two large crickets meet  [  24 3602] [0.00661886 0.99338114]
# Round 594 two large crickets meet  [  24 3608] [0.00660793 0.99339207]
# Round 595 two large crickets meet  [  24 3614] [0.00659703 0.99340297]
# Round 596 two large crickets meet  [  24 3620] [0.00658617 0.99341383]
# Round 597 two large crickets meet  [  24 3626] [0.00657534 0.99342466]
# Round 598 two large crickets meet  [  24 3632] [0.00656455 0.99343545]
# Round 599 two large crickets meet  [  24 3638] [0.0065538 0.9934462]
# Round 600 two large crickets meet  [  24 3644] [0.00654308 0.99345692]
# Round 601 two large crickets meet  [  24 3650] [0.00653239 0.99346761]
# Round 602 two large crickets meet  [  24 3656] [0.00652174 0.99347826]
# Round 603 two large crickets meet  [  24 3662] [0.00651112 0.99348888]
# Round 604 two large crickets meet  [  24 3668] [0.00650054 0.99349946]
# Round 605 two large crickets meet  [  24 3674] [0.00648999 0.99351001]
# Round 606 two large crickets meet  [  24 3680] [0.00647948 0.99352052]
# Round 607 two large crickets meet  [  24 3686] [0.006469 0.993531]
# Round 608 two large crickets meet  [  24 3692] [0.00645856 0.99354144]
# Round 609 two large crickets meet  [  24 3698] [0.00644815 0.99355185]
# Round 610 two large crickets meet  [  24 3704] [0.00643777 0.99356223]
# Round 611 two large crickets meet  [  24 3710] [0.00642742 0.99357258]
# Round 612 two large crickets meet  [  24 3716] [0.00641711 0.99358289]
# Round 613 two large crickets meet  [  24 3722] [0.00640683 0.99359317]
# Round 614 two large crickets meet  [  24 3728] [0.00639659 0.99360341]
# Round 615 two large crickets meet  [  24 3734] [0.00638638 0.99361362]
# Round 616 two large crickets meet  [  24 3740] [0.0063762 0.9936238]
# Round 617 two large crickets meet  [  24 3746] [0.00636605 0.99363395]
# Round 618 two large crickets meet  [  24 3752] [0.00635593 0.99364407]
# Round 619 two large crickets meet  [  24 3758] [0.00634585 0.99365415]
# Round 620 two large crickets meet  [  24 3764] [0.0063358 0.9936642]
# Round 621 two large crickets meet  [  24 3770] [0.00632578 0.99367422]
# Round 622 two large crickets meet  [  24 3776] [0.00631579 0.99368421]
# Round 623 two large crickets meet  [  24 3782] [0.00630583 0.99369417]
# Round 624 two large crickets meet  [  24 3788] [0.00629591 0.99370409]
# Round 625 two large crickets meet  [  24 3794] [0.00628601 0.99371399]
# Round 626 two large crickets meet  [  24 3800] [0.00627615 0.99372385]
# Round 627 two large crickets meet  [  24 3806] [0.00626632 0.99373368]
# Round 628 two large crickets meet  [  24 3812] [0.00625652 0.99374348]
# Round 629 two large crickets meet  [  24 3818] [0.00624675 0.99375325]
# Round 630 two large crickets meet  [  24 3824] [0.00623701 0.99376299]
# Round 631 two large crickets meet  [  24 3830] [0.0062273 0.9937727]
# Round 632 two large crickets meet  [  24 3836] [0.00621762 0.99378238]
# Round 633 two large crickets meet  [  24 3842] [0.00620797 0.99379203]
# Round 634 two large crickets meet  [  24 3848] [0.00619835 0.99380165]
# Round 635 two large crickets meet  [  24 3854] [0.00618876 0.99381124]
# Round 636 two large crickets meet  [  24 3860] [0.0061792 0.9938208]
# Round 637 two large crickets meet  [  24 3866] [0.00616967 0.99383033]
# Round 638 two large crickets meet  [  24 3872] [0.00616016 0.99383984]
# Round 639 two large crickets meet  [  24 3878] [0.00615069 0.99384931]
# Round 640 two large crickets meet  [  24 3884] [0.00614125 0.99385875]
# Round 641 two large crickets meet  [  24 3890] [0.00613183 0.99386817]
# Round 642 two large crickets meet  [  24 3896] [0.00612245 0.99387755]
# Round 643 two large crickets meet  [  24 3902] [0.00611309 0.99388691]
# Round 644 two large crickets meet  [  24 3908] [0.00610376 0.99389624]
# Round 645 two large crickets meet  [  24 3914] [0.00609446 0.99390554]
# Round 646 two large crickets meet  [  24 3920] [0.00608519 0.99391481]
# Round 647 two large crickets meet  [  24 3926] [0.00607595 0.99392405]
# Round 648 two large crickets meet  [  24 3932] [0.00606673 0.99393327]
# Round 649 two large crickets meet  [  24 3938] [0.00605755 0.99394245]
# Round 650 two large crickets meet  [  24 3944] [0.00604839 0.99395161]
# Round 651 two large crickets meet  [  24 3950] [0.00603926 0.99396074]
# Round 652 two large crickets meet  [  24 3956] [0.00603015 0.99396985]
# Round 653 two large crickets meet  [  24 3962] [0.00602107 0.99397893]
# Round 654 two large crickets meet  [  24 3968] [0.00601202 0.99398798]
# Round 655 two large crickets meet  [  24 3974] [0.006003 0.993997]
# Round 656 two large crickets meet  [  24 3980] [0.00599401 0.99400599]
# Round 657 two large crickets meet  [  24 3986] [0.00598504 0.99401496]
# Round 658 two large crickets meet  [  24 3992] [0.0059761 0.9940239]
# Round 659 two large crickets meet  [  24 3998] [0.00596718 0.99403282]
# Round 660 two large crickets meet  [  24 4004] [0.00595829 0.99404171]
# Round 661 two large crickets meet  [  24 4010] [0.00594943 0.99405057]
# Round 662 two large crickets meet  [  24 4016] [0.00594059 0.99405941]
# Round 663 two large crickets meet  [  24 4022] [0.00593178 0.99406822]
# Round 664 two large crickets meet  [  24 4028] [0.005923 0.994077]
# Round 665 two large crickets meet  [  24 4034] [0.00591424 0.99408576]
# Round 666 two large crickets meet  [  24 4040] [0.00590551 0.99409449]
# Round 667 two large crickets meet  [  24 4046] [0.00589681 0.99410319]
# Round 668 two large crickets meet  [  24 4052] [0.00588813 0.99411187]
# Round 669 two large crickets meet  [  24 4058] [0.00587947 0.99412053]
# Round 670 two large crickets meet  [  24 4064] [0.00587084 0.99412916]
# Round 671 two large crickets meet  [  24 4070] [0.00586224 0.99413776]
# Round 672 two large crickets meet  [  24 4076] [0.00585366 0.99414634]
# Round 673 two large crickets meet  [  24 4082] [0.0058451 0.9941549]
# Round 674 two large crickets meet  [  24 4088] [0.00583658 0.99416342]
# Round 675 two large crickets meet  [  24 4094] [0.00582807 0.99417193]
# Round 676 two large crickets meet  [  24 4100] [0.00581959 0.99418041]
# Round 677 two large crickets meet  [  24 4106] [0.00581114 0.99418886]
# Round 678 two large crickets meet  [  24 4112] [0.00580271 0.99419729]
# Round 679 two large crickets meet  [  24 4118] [0.0057943 0.9942057]
# Round 680 two large crickets meet  [  24 4124] [0.00578592 0.99421408]
# Round 681 two large crickets meet  [  24 4130] [0.00577756 0.99422244]
# Round 682 two large crickets meet  [  24 4136] [0.00576923 0.99423077]
# Round 683 two large crickets meet  [  24 4142] [0.00576092 0.99423908]
# ...
# Round 775 two large crickets meet  [  25 4696] [0.00529549 0.99470451]
# Round 776 two large crickets meet  [  25 4702] [0.00528877 0.99471123]
# Round 777 two large crickets meet  [  25 4708] [0.00528206 0.99471794]
# Round 778 two large crickets meet  [  25 4714] [0.00527537 0.99472463]
# Round 779 two large crickets meet  [  25 4720] [0.0052687 0.9947313]
# Round 780 two large crickets meet  [  25 4726] [0.00526205 0.99473795]
# Round 781 two large crickets meet  [  25 4732] [0.00525541 0.99474459]
# Round 782 two large crickets meet  [  25 4738] [0.00524879 0.99475121]
# Round 783 two large crickets meet  [  25 4744] [0.00524219 0.99475781]
# Round 784 two large crickets meet  [  25 4750] [0.0052356 0.9947644]
# Round 785 two large crickets meet  [  25 4756] [0.00522903 0.99477097]
# Round 786 two large crickets meet  [  25 4762] [0.00522248 0.99477752]
# Round 787 two large crickets meet  [  25 4768] [0.00521594 0.99478406]
# Round 788 two large crickets meet  [  25 4774] [0.00520942 0.99479058]
# Round 789 two large crickets meet  [  25 4780] [0.00520291 0.99479709]
# Round 790 two large crickets meet  [  25 4786] [0.00519642 0.99480358]
# Round 791 two large crickets meet  [  25 4792] [0.00518995 0.99481005]
# Round 792 two large crickets meet  [  25 4798] [0.0051835 0.9948165]
# Round 793 two large crickets meet  [  25 4804] [0.00517706 0.99482294]
# Round 794 two large crickets meet  [  25 4810] [0.00517063 0.99482937]
# Round 795 two large crickets meet  [  25 4816] [0.00516422 0.99483578]
# Round 796 two large crickets meet  [  25 4822] [0.00515783 0.99484217]
# Round 797 two large crickets meet  [  25 4828] [0.00515145 0.99484855]
# Round 798 two large crickets meet  [  25 4834] [0.00514509 0.99485491]
# Round 799 two large crickets meet  [  25 4840] [0.00513875 0.99486125]
# Round 800 two large crickets meet  [  25 4846] [0.00513242 0.99486758]
# Round 801 two large crickets meet  [  25 4852] [0.0051261 0.9948739]
# Round 802 two large crickets meet  [  25 4858] [0.0051198 0.9948802]
# Round 803 two large crickets meet  [  25 4864] [0.00511352 0.99488648]
# Round 804 two large crickets meet  [  25 4870] [0.00510725 0.99489275]
# Round 805 two large crickets meet  [  25 4876] [0.005101 0.994899]
# Round 806 two large crickets meet  [  25 4882] [0.00509476 0.99490524]
# Round 807 two large crickets meet  [  25 4888] [0.00508854 0.99491146]
# Round 808 two large crickets meet  [  25 4894] [0.00508233 0.99491767]
# Round 809 two large crickets meet  [  25 4900] [0.00507614 0.99492386]
# Round 810 two large crickets meet  [  25 4906] [0.00506997 0.99493003]
# Round 811 two large crickets meet  [  25 4912] [0.0050638 0.9949362]
# Round 812 two large crickets meet  [  25 4918] [0.00505766 0.99494234]
# Round 813 two large crickets meet  [  25 4924] [0.00505153 0.99494847]
# Round 814 two large crickets meet  [  25 4930] [0.00504541 0.99495459]
# Round 815 two large crickets meet  [  25 4936] [0.00503931 0.99496069]
# Round 816 two large crickets meet  [  25 4942] [0.00503322 0.99496678]
# Round 817 two large crickets meet  [  25 4948] [0.00502715 0.99497285]
# Round 818 two large crickets meet  [  25 4954] [0.00502109 0.99497891]
# Round 819 two large crickets meet  [  25 4960] [0.00501505 0.99498495]
# Round 820 two large crickets meet  [  25 4966] [0.00500902 0.99499098]
# Round 821 two large crickets meet  [  25 4972] [0.005003 0.994997]
# Round 822 two large crickets meet  [  25 4978] [0.004997 0.995003]
# Round 823 two large crickets meet  [  25 4984] [0.00499102 0.99500898]
# Round 824 two large crickets meet  [  25 4990] [0.00498504 0.99501496]
# Round 825 two large crickets meet  [  25 4996] [0.00497909 0.99502091]
# Round 826 two large crickets meet  [  25 5002] [0.00497315 0.99502685]
# Round 827 two large crickets meet  [  25 5008] [0.00496722 0.99503278]
# Round 828 two large crickets meet  [  25 5014] [0.0049613 0.9950387]
# Round 829 two large crickets meet  [  25 5020] [0.0049554 0.9950446]
# Round 830 two large crickets meet  [  25 5026] [0.00494951 0.99505049]
# Round 831 two large crickets meet  [  25 5032] [0.00494364 0.99505636]
# Round 832 two large crickets meet  [  25 5038] [0.00493778 0.99506222]
# Round 833 two large crickets meet  [  25 5044] [0.00493194 0.99506806]
# Round 834 two large crickets meet  [  25 5050] [0.00492611 0.99507389]
# Round 835 a small meets a large    [  26 5058] [0.00511408 0.99488592]
# Round 836 two large crickets meet  [  26 5064] [0.00510806 0.99489194]
# Round 837 two large crickets meet  [  26 5070] [0.00510204 0.99489796]
# Round 838 two large crickets meet  [  26 5076] [0.00509604 0.99490396]
# Round 839 two large crickets meet  [  26 5082] [0.00509005 0.99490995]
# Round 840 two large crickets meet  [  26 5088] [0.00508408 0.99491592]
# Round 841 two large crickets meet  [  26 5094] [0.00507813 0.99492187]
# Round 842 two large crickets meet  [  26 5100] [0.00507218 0.99492782]
# Round 843 two large crickets meet  [  26 5106] [0.00506625 0.99493375]
# Round 844 two large crickets meet  [  26 5112] [0.00506033 0.99493967]
# Round 845 two large crickets meet  [  26 5118] [0.00505443 0.99494557]
# Round 846 two large crickets meet  [  26 5124] [0.00504854 0.99495146]
# Round 847 two large crickets meet  [  26 5130] [0.00504267 0.99495733]
# Round 848 two large crickets meet  [  26 5136] [0.00503681 0.99496319]
# Round 849 two large crickets meet  [  26 5142] [0.00503096 0.99496904]
# Round 850 two large crickets meet  [  26 5148] [0.00502513 0.99497487]
# Round 851 two large crickets meet  [  26 5154] [0.00501931 0.99498069]
# Round 852 two large crickets meet  [  26 5160] [0.0050135 0.9949865]
# Round 853 two large crickets meet  [  26 5166] [0.0050077 0.9949923]
# Round 854 two large crickets meet  [  26 5172] [0.00500192 0.99499808]
# Round 855 two large crickets meet  [  26 5178] [0.00499616 0.99500384]
# Round 856 two large crickets meet  [  26 5184] [0.0049904 0.9950096]
# Round 857 two large crickets meet  [  26 5190] [0.00498466 0.99501534]
# Round 858 two large crickets meet  [  26 5196] [0.00497894 0.99502106]
# Round 859 two large crickets meet  [  26 5202] [0.00497322 0.99502678]
# Round 860 two large crickets meet  [  26 5208] [0.00496752 0.99503248]
# Round 861 two large crickets meet  [  26 5214] [0.00496183 0.99503817]
# Round 862 two large crickets meet  [  26 5220] [0.00495616 0.99504384]
# Round 863 two large crickets meet  [  26 5226] [0.0049505 0.9950495]
# Round 864 two large crickets meet  [  26 5232] [0.00494485 0.99505515]
# Round 865 two large crickets meet  [  26 5238] [0.00493921 0.99506079]
# Round 866 two large crickets meet  [  26 5244] [0.00493359 0.99506641]
# Round 867 two large crickets meet  [  26 5250] [0.00492798 0.99507202]
# Round 868 two large crickets meet  [  26 5256] [0.00492238 0.99507762]
# Round 869 two large crickets meet  [  26 5262] [0.00491679 0.99508321]
# Round 870 two large crickets meet  [  26 5268] [0.00491122 0.99508878]
# Round 871 two large crickets meet  [  26 5274] [0.00490566 0.99509434]
# Round 872 two large crickets meet  [  26 5280] [0.00490011 0.99509989]
# Round 873 two large crickets meet  [  26 5286] [0.00489458 0.99510542]
# Round 874 two large crickets meet  [  26 5292] [0.00488906 0.99511094]
# Round 875 two large crickets meet  [  26 5298] [0.00488355 0.99511645]
# Round 876 two large crickets meet  [  26 5304] [0.00487805 0.99512195]
# Round 877 two large crickets meet  [  26 5310] [0.00487256 0.99512744]
# Round 878 two large crickets meet  [  26 5316] [0.00486709 0.99513291]
# Round 879 two large crickets meet  [  26 5322] [0.00486163 0.99513837]
# Round 880 two large crickets meet  [  26 5328] [0.00485618 0.99514382]
# Round 881 two large crickets meet  [  26 5334] [0.00485075 0.99514925]
# Round 882 two large crickets meet  [  26 5340] [0.00484532 0.99515468]
# Round 883 two large crickets meet  [  26 5346] [0.00483991 0.99516009]
# Round 884 two large crickets meet  [  26 5352] [0.00483451 0.99516549]
# Round 885 two large crickets meet  [  26 5358] [0.00482912 0.99517088]
# Round 886 two large crickets meet  [  26 5364] [0.00482375 0.99517625]
# Round 887 two large crickets meet  [  26 5370] [0.00481838 0.99518162]
# Round 888 two large crickets meet  [  26 5376] [0.00481303 0.99518697]
# Round 889 two large crickets meet  [  26 5382] [0.00480769 0.99519231]
# Round 890 two large crickets meet  [  26 5388] [0.00480236 0.99519764]
# Round 891 two large crickets meet  [  26 5394] [0.00479705 0.99520295]
# Round 892 two large crickets meet  [  26 5400] [0.00479174 0.99520826]
# Round 893 two large crickets meet  [  26 5406] [0.00478645 0.99521355]
# Round 894 two large crickets meet  [  26 5412] [0.00478117 0.99521883]
# Round 895 a small meets a large    [  27 5420] [0.00495686 0.99504314]
# Round 896 two large crickets meet  [  27 5426] [0.0049514 0.9950486]
# Round 897 two large crickets meet  [  27 5432] [0.00494596 0.99505404]
# Round 898 two large crickets meet  [  27 5438] [0.00494053 0.99505947]
# Round 899 two large crickets meet  [  27 5444] [0.00493511 0.99506489]
# Round 900 two large crickets meet  [  27 5450] [0.00492971 0.99507029]
# Round 901 two large crickets meet  [  27 5456] [0.00492431 0.99507569]
# Round 902 two large crickets meet  [  27 5462] [0.00491893 0.99508107]
# Round 903 two large crickets meet  [  27 5468] [0.00491356 0.99508644]
# Round 904 two large crickets meet  [  27 5474] [0.0049082 0.9950918]
# Round 905 two large crickets meet  [  27 5480] [0.00490285 0.99509715]
# Round 906 two large crickets meet  [  27 5486] [0.00489751 0.99510249]
# Round 907 two large crickets meet  [  27 5492] [0.00489219 0.99510781]
# Round 908 two large crickets meet  [  27 5498] [0.00488688 0.99511312]
# Round 909 two large crickets meet  [  27 5504] [0.00488158 0.99511842]
# Round 910 two large crickets meet  [  27 5510] [0.00487629 0.99512371]
# Round 911 two large crickets meet  [  27 5516] [0.00487101 0.99512899]
# Round 912 two large crickets meet  [  27 5522] [0.00486574 0.99513426]
# Round 913 two large crickets meet  [  27 5528] [0.00486049 0.99513951]
# Round 914 two large crickets meet  [  27 5534] [0.00485524 0.99514476]
# Round 915 two large crickets meet  [  27 5540] [0.00485001 0.99514999]
# Round 916 two large crickets meet  [  27 5546] [0.00484479 0.99515521]
# Round 917 two large crickets meet  [  27 5552] [0.00483958 0.99516042]
# Round 918 two large crickets meet  [  27 5558] [0.00483438 0.99516562]
# Round 919 two large crickets meet  [  27 5564] [0.00482919 0.99517081]
# Round 920 two large crickets meet  [  27 5570] [0.00482401 0.99517599]
# Round 921 two large crickets meet  [  27 5576] [0.00481885 0.99518115]
# Round 922 two large crickets meet  [  27 5582] [0.00481369 0.99518631]
# Round 923 two large crickets meet  [  27 5588] [0.00480855 0.99519145]
# Round 924 two large crickets meet  [  27 5594] [0.00480342 0.99519658]
# Round 925 two large crickets meet  [  27 5600] [0.00479829 0.99520171]
# Round 926 two large crickets meet  [  27 5606] [0.00479318 0.99520682]
# Round 927 two large crickets meet  [  27 5612] [0.00478808 0.99521192]
# Round 928 two large crickets meet  [  27 5618] [0.00478299 0.99521701]
# Round 929 two large crickets meet  [  27 5624] [0.00477792 0.99522208]
# Round 930 two large crickets meet  [  27 5630] [0.00477285 0.99522715]
# Round 931 two large crickets meet  [  27 5636] [0.00476779 0.99523221]
# Round 932 two large crickets meet  [  27 5642] [0.00476274 0.99523726]
# Round 933 two large crickets meet  [  27 5648] [0.00475771 0.99524229]
# Round 934 two large crickets meet  [  27 5654] [0.00475268 0.99524732]
# Round 935 two large crickets meet  [  27 5660] [0.00474767 0.99525233]
# Round 936 two large crickets meet  [  27 5666] [0.00474267 0.99525733]
# Round 937 two large crickets meet  [  27 5672] [0.00473767 0.99526233]
# Round 938 two large crickets meet  [  27 5678] [0.00473269 0.99526731]
# Round 939 two large crickets meet  [  27 5684] [0.00472772 0.99527228]
# Round 940 two large crickets meet  [  27 5690] [0.00472276 0.99527724]
# Round 941 two large crickets meet  [  27 5696] [0.00471781 0.99528219]
# Round 942 two large crickets meet  [  27 5702] [0.00471286 0.99528714]
# Round 943 two large crickets meet  [  27 5708] [0.00470793 0.99529207]
# Round 944 two large crickets meet  [  27 5714] [0.00470301 0.99529699]
# Round 945 two large crickets meet  [  27 5720] [0.0046981 0.9953019]
# Round 946 two large crickets meet  [  27 5726] [0.0046932 0.9953068]
# Round 947 two large crickets meet  [  27 5732] [0.00468831 0.99531169]
# Round 948 two large crickets meet  [  27 5738] [0.00468343 0.99531657]
# Round 949 two large crickets meet  [  27 5744] [0.00467857 0.99532143]
# Round 950 two large crickets meet  [  27 5750] [0.00467371 0.99532629]
# Round 951 two large crickets meet  [  27 5756] [0.00466886 0.99533114]
# Round 952 two large crickets meet  [  27 5762] [0.00466402 0.99533598]
# Round 953 two large crickets meet  [  27 5768] [0.00465919 0.99534081]
# Round 954 two large crickets meet  [  27 5774] [0.00465437 0.99534563]
# Round 955 two large crickets meet  [  27 5780] [0.00464956 0.99535044]
# Round 956 two large crickets meet  [  27 5786] [0.00464476 0.99535524]
# Round 957 two large crickets meet  [  27 5792] [0.00463997 0.99536003]
# Round 958 two large crickets meet  [  27 5798] [0.00463519 0.99536481]
# Round 959 two large crickets meet  [  27 5804] [0.00463042 0.99536958]
# Round 960 two large crickets meet  [  27 5810] [0.00462566 0.99537434]
# Round 961 two large crickets meet  [  27 5816] [0.00462091 0.99537909]
# Round 962 two large crickets meet  [  27 5822] [0.00461617 0.99538383]
# Round 963 two large crickets meet  [  27 5828] [0.00461144 0.99538856]
# Round 964 two large crickets meet  [  27 5834] [0.00460672 0.99539328]
# Round 965 two large crickets meet  [  27 5840] [0.00460201 0.99539799]
# Round 966 two large crickets meet  [  27 5846] [0.00459731 0.99540269]
# Round 967 two large crickets meet  [  27 5852] [0.00459262 0.99540738]
# Round 968 two large crickets meet  [  27 5858] [0.00458794 0.99541206]
# Round 969 two large crickets meet  [  27 5864] [0.00458326 0.99541674]
# Round 970 two large crickets meet  [  27 5870] [0.0045786 0.9954214]
# Round 971 two large crickets meet  [  27 5876] [0.00457395 0.99542605]
# Round 972 two large crickets meet  [  27 5882] [0.0045693 0.9954307]
# Round 973 two large crickets meet  [  27 5888] [0.00456467 0.99543533]
# Round 974 two large crickets meet  [  27 5894] [0.00456004 0.99543996]
# Round 975 two large crickets meet  [  27 5900] [0.00455542 0.99544458]
# Round 976 two large crickets meet  [  27 5906] [0.00455082 0.99544918]
# Round 977 two large crickets meet  [  27 5912] [0.00454622 0.99545378]
# Round 978 two large crickets meet  [  27 5918] [0.00454163 0.99545837]
# Round 979 two large crickets meet  [  27 5924] [0.00453705 0.99546295]
# Round 980 two large crickets meet  [  27 5930] [0.00453248 0.99546752]
# Round 981 two large crickets meet  [  27 5936] [0.00452792 0.99547208]
# Round 982 two large crickets meet  [  27 5942] [0.00452337 0.99547663]
# Round 983 two large crickets meet  [  27 5948] [0.00451883 0.99548117]
# Round 984 two large crickets meet  [  27 5954] [0.0045143 0.9954857]
# Round 985 two large crickets meet  [  27 5960] [0.00450977 0.99549023]
# Round 986 two large crickets meet  [  27 5966] [0.00450526 0.99549474]
# Round 987 two large crickets meet  [  27 5972] [0.00450075 0.99549925]
# Round 988 two large crickets meet  [  27 5978] [0.00449625 0.99550375]
# Round 989 two large crickets meet  [  27 5984] [0.00449177 0.99550823]
# Round 990 two large crickets meet  [  27 5990] [0.00448729 0.99551271]
# Round 991 two large crickets meet  [  27 5996] [0.00448282 0.99551718]
# Round 992 two large crickets meet  [  27 6002] [0.00447835 0.99552165]
# Round 993 two large crickets meet  [  27 6008] [0.0044739 0.9955261]
# Round 994 two large crickets meet  [  27 6014] [0.00446946 0.99553054]
# Round 995 two large crickets meet  [  27 6020] [0.00446502 0.99553498]
# Round 996 two large crickets meet  [  27 6026] [0.0044606 0.9955394]
# Round 997 two large crickets meet  [  27 6032] [0.00445618 0.99554382]
# Round 998 two large crickets meet  [  27 6038] [0.00445177 0.99554823]
# Round 999 two large crickets meet  [  27 6044] [0.00444737 0.99555263]
# Round 1000 two large crickets meet  [  27 6050] [0.00444298 0.99555702]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__
# 1) If all the crickets are small, each round the number of small crickets increases by 10. After 100 rounds there are 1000 more small crickets than there was initially.
#
# 2) If all the crickets are large, each round the number of large crickets increases by 6. After 100 rounds there are 600 more large crickets than there was initially.
#
# 3) Yes the fractions converge. The number of small crickets converges to 0 and the number of large crickets converges to 1.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 4,4 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (simulation)')

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__:
# 1) For all the intial conditions, the output is very similar to the output of the previous code. The larger crickets tend to dominate the smaller crickets when there are an equal number of small and large crickets, initially.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
### Part 1 ###
print('Part 1 - Theta vs Time')

# Code given above
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(theta,t):
    diag = np.array([
        [theta[0], 0       ],
        [0       , theta[1]]
    ])
    Ftheta = F @ theta # short hand for dot product
    ones = np.ones_like(theta)
#     print(diag.shape, Ftheta.shape, ones.shape)
#     print(np.outer(ones,theta))
    
    return diag @ (Ftheta - (np.outer(ones, theta) @ Ftheta))

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

theta0 = ninit[0] / (ninit[0]+ninit[1])
theta1 = ninit[1] / (ninit[0]+ninit[1])
theta_init = [theta0, theta1]

theta=odeint(f,theta_init,time)

plt.plot(time,theta[:,0],'orange')
plt.plot(time,theta[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,theta[800,0], r'small',fontsize=14)
plt.text(1.1,theta[800,1], r'large',fontsize=14)
plt.ylabel('theta')
plt.title("Theta vs Time")
plt.show()


### Part 2 ###
print("\n Part 2 - Plot of F'n h")

time = np.linspace(0, 1, 1000)

def h(theta):
    diag = np.array([
        [theta[0], 0       ],
        [0       , theta[1]]
    ])
    Ftheta = F @ theta # short hand for dot product
    ones = np.ones_like(theta)
#     print(diag.shape, Ftheta.shape, ones.shape)
#     print(np.outer(ones,theta))
    
    return diag @ (Ftheta - (np.outer(ones, theta) @ Ftheta))

theta = []
for t in time:
    theta0 = h([t, 1-t])[0]
    theta.append(theta0)

plt.plot(time, theta,'red')
plt.title("Plot of F'n h")
plt.xlabel('theta[0]')
plt.ylabel('h(theta[0])')
plt.ylim(-0.7, 0.1)
plt.show()
# Out:
# Part 1 - Theta vs Time
#  Part 2 - Plot of F'n h

# %% [markdown]
# __Answer:__
# 3) The zeros of h are 0 and 1. The only stable equilibrium point is when theta[0] is equal to 0.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
### Part 1 ###
print('Part 1 - Theta vs Time')

# Code given above
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[3,1],[5,0]])  # fitness matrix

def f(theta,t):
    diag = np.array([
        [theta[0], 0       ],
        [0       , theta[1]]
    ])
    Ftheta = F @ theta # short hand for dot product
    ones = np.ones_like(theta)
#     print(diag.shape, Ftheta.shape, ones.shape)
#     print(np.outer(ones,theta))
    
    return diag @ (Ftheta - (np.outer(ones, theta) @ Ftheta))

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

theta0 = ninit[0] / (ninit[0]+ninit[1])
theta1 = ninit[1] / (ninit[0]+ninit[1])
theta_init = [theta0, theta1]

theta=odeint(f,theta_init,time)

plt.plot(time,theta[:,0],'orange')
plt.plot(time,theta[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,theta[800,0], r'doves',fontsize=14)
plt.text(1.1,theta[800,1], r'hawks',fontsize=14)
plt.ylabel('theta')
plt.title("Theta vs Time")
plt.ylim(0.35,0.65)
plt.show()


### Part 2 ###
print("\n Part 2 - Plot of F'n h")

time = np.linspace(0, 1, 1000)

def h(theta):
    diag = np.array([
        [theta[0], 0       ],
        [0       , theta[1]]
    ])
    Ftheta = F @ theta # short hand for dot product
    ones = np.ones_like(theta)
#     print(diag.shape, Ftheta.shape, ones.shape)
#     print(np.outer(ones,theta))
    
    return diag @ (Ftheta - (np.outer(ones, theta) @ Ftheta))

theta = []
for t in time:
    theta0 = h([t, 1-t])[0]
    theta.append(theta0)

plt.plot(time, theta,'red')
plt.title("Plot of F'n h")
plt.xlabel('theta[0]')
plt.ylabel('h(theta[0])')
plt.ylim(-0.25, 0.1)
plt.show()
# Out:
# Part 1 - Theta vs Time
#  Part 2 - Plot of F'n h

# %% [markdown]
# __Answer:__
# 2) The equilibrium points for h are 0, 1/3, and 1. 0 and 1 can only happen if there is either only doves or only hawks. Therefore the only stable equilibrium point is when theta[0] equals 1/3.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
### Part 1 ###
print('Part 1 - Theta vs Time')

# Code given above
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F = np.array([[0,5,-5], [-5,0,5], [5, -5, 0]])  # fitness matrix

def f(theta,t):
    diag = np.array([
        [theta[0], 0       ,0        ],
        [0       , theta[1],0        ],
        [0       , 0       , theta[2]]
    ])
    Ftheta = F @ theta # short hand for dot product
    ones = np.ones_like(theta)
#     print(diag.shape, Ftheta.shape, ones.shape)
#     print(np.outer(ones,theta))
    
    return diag @ (Ftheta - (np.outer(ones, theta) @ Ftheta))

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0, 3, 1000)

theta_init = [1/4, 1/4, 1/2]

theta=odeint(f,theta_init,time)

plt.plot(time,theta[:,0],'orange',label='rabbits')
plt.plot(time,theta[:,1],'blue'  ,label='coyotes')
plt.plot(time,theta[:,2],'green' ,label='owls')
plt.xlabel('time')
plt.ylabel('theta')
plt.title("Theta vs Time")
plt.ylim(0.15,0.55)
plt.legend()
plt.show()
# Out:
# Part 1 - Theta vs Time

# %% [markdown]
# __Answer:__
# 1) For this kind of oscillating pattern to occur, the 3 animals coexist and rely on each other to survive. If there isn't enough of one animal type, one animal type usually suffers and the other usually benefits. Over time this pattern continues which creates these oscillating cycles.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
